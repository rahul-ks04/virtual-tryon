# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content
# !git clone https://github.com/rahul-ks04/virtual-tryon.git
# %cd virtual-tryon

# %%
# !ls /content/drive/MyDrive/virtual_tryon_project

# %%
# !pip install kaggle

# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/virtual_tryon_project/kaggle/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list | head

# %%
# %cd /content/drive/MyDrive/virtual_tryon_project/data

# %%
# !kaggle datasets download -d marquis03/high-resolution-viton-zalando-dataset

# %%
# !unzip high-resolution-viton-zalando-dataset.zip -d viton_hd

# %%
# !ls viton_hd

# %%
PROJECT_ROOT = "/content/drive/MyDrive/virtual_tryon_project"
DATA_ROOT = f"{PROJECT_ROOT}/data/viton_hd"
CKPT_ROOT = f"{PROJECT_ROOT}/checkpoints"

# %%
# !git config --global user.name "Virtual TryOn Team"
# !git config --global user.email "viton.team1@gmail.com"

# %%
# !git config --global --list

# %%
# !rm notebooks/00_setup_dataset.ipynb

# %%
# !git config --global user.name "Virtual TryOn Team"
# !git config --global user.email "viton.team1@gmail.com"

# %%
# %pwd

# %%
# !mv 00_setup_dataset.ipynb /content/virtual-tryon/notebooks/

# %%
# !git status
# !git add notebooks/00_setup_dataset.ipynb
# !git commit -m "Remove dummy dataset setup notebook"

# %%
# !git push https://rahul-ks04:<API TOKEN>j@github.com/rahul-ks04/virtual-tryon.git
